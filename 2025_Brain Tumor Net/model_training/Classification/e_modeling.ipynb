# %% [markdown]
# # Brain Tumor Classification With SegFormer's Segmentation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import tensorflow_addons as tfa
import os
import cv2

# %% [markdown]
# ### Data Preparation

# %%
def get_df(original_images_dir, masked_images_dir):
    class_names = os.listdir(original_images_dir)

    original_file_path = []
    masked_file_path = []
    classes = []
    for class_name in class_names:
        for file_name in os.listdir(os.path.join(original_images_dir, class_name)):
            masked_file_path.append(os.path.join(masked_images_dir, class_name, file_name))
            original_file_path.append(os.path.join(original_images_dir, class_name, file_name))
            classes.append(class_name)

    df = pd.DataFrame({
        "OriginalPath": original_file_path,
        "MaskedPath": masked_file_path,
        "Class": classes
    })

    return df

# %%
train_df = get_df("../data/original/original/Training", "../data/segformer/segformer/Training")
test_df = get_df("../data/original/original/Testing", "../data/segformer/segformer/Testing")

# %% [markdown]
# ### Data Preprocessing

# %%
from sklearn.model_selection import train_test_split

# %%
valid_df, test_df = train_test_split(test_df, test_size = 0.5, random_state = 42, stratify = test_df["Class"], shuffle = True)

# %%
class_names = sorted(train_df['Class'].unique())
class_to_index = {name: i for i, name in enumerate(class_names)}

def load_and_combine(image_path, mask_path):
    # Load and decode image and mask
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=1)  # Use channels=1 for grayscale
    image = tf.image.convert_image_dtype(image, tf.float32)

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.convert_image_dtype(mask, tf.float32)

    # Resize if needed (optional)
    image = tf.image.resize(image, [224, 224])
    mask = tf.image.resize(mask, [224, 224])

    # Concatenate along the channel axis
    combined = tf.concat([image, mask], axis = -1)  # Shape: (H, W, 2)

    return combined

def preprocess(image_path, mask_path, label):
    combined = load_and_combine(image_path, mask_path)
    label_one_hot = tf.one_hot(label, depth=4)
    return combined, label_one_hot

def create_dataset(df, class_to_index, batch_size=32, shuffle=True):
    image_paths = df["OriginalPath"].values
    mask_paths = df["MaskedPath"].values
    labels = df["Class"].map(class_to_index).values

    ds = tf.data.Dataset.from_tensor_slices((image_paths, mask_paths, labels))
    ds = ds.map(lambda x, y, z: preprocess(x, y, z), num_parallel_calls=tf.data.AUTOTUNE)

    if shuffle:
        ds = ds.shuffle(buffer_size=len(df))

    ds = ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return ds

# %%
train_ds = create_dataset(train_df, class_to_index)
valid_ds = create_dataset(valid_df, class_to_index, shuffle = False)
test_ds = create_dataset(test_df, class_to_index, shuffle = False)

# %% [markdown]
# ### Modeling

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
y_true = test_df["Class"].map(class_to_index)

# %%
y_true_one_hot = tf.keras.utils.to_categorical(y_true, num_classes = 4)

# %% [markdown]
# ##### 1. CNN

# %%
def get_feature_extractor():
    cnn = tf.keras.models.Sequential()    

    # Convulational Layer 1
    cnn.add(tf.keras.layers.Conv2D(
        filters = 32, 
        kernel_size = 3, 
        input_shape = [224, 224, 2], 
        kernel_regularizer = tf.keras.regularizers.l2(0.00005),
        padding = "same"
    ))
    cnn.add(tf.keras.layers.BatchNormalization())
    cnn.add(tf.keras.layers.ReLU())

    # Pooling Layer 1
    cnn.add(tf.keras.layers.MaxPool2D(
        pool_size = 2, 
        strides = 2
    ))

    # Convulational Layer 2
    cnn.add(tf.keras.layers.Conv2D(
        filters = 64, 
        kernel_size = 3, 
        kernel_regularizer = tf.keras.regularizers.l2(0.00005),
        padding = "same"
    ))
    cnn.add(tf.keras.layers.BatchNormalization())
    cnn.add(tf.keras.layers.ReLU())

    # Pooling Layer 2
    cnn.add(tf.keras.layers.MaxPool2D(
        pool_size = 2, 
        strides = 2
    ))

    # Convulational Layer 3
    cnn.add(tf.keras.layers.Conv2D(
        filters = 128, 
        kernel_size = 3, 
        kernel_regularizer = tf.keras.regularizers.l2(0.00005),
        padding = "same"
    ))
    cnn.add(tf.keras.layers.BatchNormalization())
    cnn.add(tf.keras.layers.ReLU())

    # Pooling Layer 3
    cnn.add(tf.keras.layers.MaxPool2D(
        pool_size = 2, 
        strides = 2
    ))

    # Convulational Layer 4
    cnn.add(tf.keras.layers.Conv2D(
        filters = 128, 
        kernel_size = 3, 
        kernel_regularizer = tf.keras.regularizers.l2(0.00005),
        padding = "same"
    ))
    cnn.add(tf.keras.layers.BatchNormalization())
    cnn.add(tf.keras.layers.ReLU())

    # Pooling Layer 4
    cnn.add(tf.keras.layers.MaxPool2D(
        pool_size = 2, 
        strides = 2
    ))  
 
    # Flatten Layer 
    cnn.add(tf.keras.layers.Flatten())  

    return cnn

# %%
cnn = get_feature_extractor()

# Fully Connected Layer 1
cnn.add(tf.keras.layers.Dense(
    units = 128,
    kernel_regularizer = tf.keras.regularizers.l2(0.00005)
))
cnn.add(tf.keras.layers.BatchNormalization())
cnn.add(tf.keras.layers.ReLU())


# Droput Layer
cnn.add(tf.keras.layers.Dropout(0.4))

# Output Layer
cnn.add(tf.keras.layers.Dense(
    units = 4, 
    activation = "softmax"
))

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      608
#
#  batch_normalization (BatchN  (None, 224, 224, 32)     128
#  ormalization)
#
#  re_lu (ReLU)                (None, 224, 224, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)      18496
#
#  batch_normalization_1 (Batc  (None, 112, 112, 64)     256
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 112, 112, 64)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 56, 56, 128)      512
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 56, 56, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 28, 28, 128)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 128)               3211392
#
#  batch_normalization_4 (Batc  (None, 128)              512
#  hNormalization)
#
#  re_lu_4 (ReLU)              (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 3,454,372
# Trainable params: 3,453,412
# Non-trainable params: 960
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor = "val_loss", 
    patience = 10, 
    restore_best_weights = True
)

# %%
cnn.compile(
    optimizer = tf.keras.optimizers.Adam(
        learning_rate = tf.keras.optimizers.schedules.ExponentialDecay(
            initial_learning_rate = 1e-4,
            decay_steps = 1000,
            decay_rate = 0.95
        )
    ), 
    loss = "categorical_crossentropy", 
    metrics = [tf.keras.metrics.Recall()]
)

# %%
history = cnn.fit(
    train_ds, 
    validation_data = valid_ds, 
    epochs = 100, 
    callbacks = [early_stopping]
)
# Out:
# Epoch 1/100
# 179/179 [==============================] - 24s 88ms/step - loss: 0.5381 - recall: 0.7687 - val_loss: 1.8519 - val_recall: 0.2290
# Epoch 2/100
# 179/179 [==============================] - 17s 85ms/step - loss: 0.2713 - recall: 0.9039 - val_loss: 1.1590 - val_recall: 0.4244
# Epoch 3/100
# 179/179 [==============================] - 17s 85ms/step - loss: 0.1742 - recall: 0.9461 - val_loss: 0.3791 - val_recall: 0.8443
# Epoch 4/100
# 179/179 [==============================] - 18s 85ms/step - loss: 0.1219 - recall: 0.9694 - val_loss: 0.3023 - val_recall: 0.8870
# Epoch 5/100
# 179/179 [==============================] - 18s 85ms/step - loss: 0.0965 - recall: 0.9814 - val_loss: 0.1767 - val_recall: 0.9542
# Epoch 6/100
# 179/179 [==============================] - 18s 85ms/step - loss: 0.0804 - recall: 0.9867 - val_loss: 0.2264 - val_recall: 0.9069
# Epoch 7/100
# 179/179 [==============================] - 18s 85ms/step - loss: 0.0600 - recall: 0.9946 - val_loss: 0.1583 - val_recall: 0.9527
# Epoch 8/100
# 179/179 [==============================] - 18s 85ms/step - loss: 0.0553 - recall: 0.9951 - val_loss: 0.1586 - val_recall: 0.9450
# Epoch 9/100
# 179/179 [==============================] - 18s 86ms/step - loss: 0.0581 - recall: 0.9930 - val_loss: 0.1540 - val_recall: 0.9557
# Epoch 10/100
# 179/179 [==============================] - 18s 86ms/step - loss: 0.0463 - recall: 0.9982 - val_loss: 0.1361 - val_recall: 0.9588
# Epoch 11/100
# 179/179 [==============================] - 19s 87ms/step - loss: 0.0407 - recall: 0.9988 - val_loss: 0.1266 - val_recall: 0.9649
# Epoch 12/100
# 179/179 [==============================] - 19s 87ms/step - loss: 0.0406 - recall: 0.9989 - val_loss: 0.1245 - val_recall: 0.9664
# Epoch 13/100
# 179/179 [==============================] - 19s 87ms/step - loss: 0.0373 - recall: 0.9995 - val_loss: 0.1283 - val_recall: 0.9649
# Epoch 14/100
# 179/179 [==============================] - 19s 88ms/step - loss: 0.0366 - recall: 0.9986 - val_loss: 0.1613 - val_recall: 0.9542
# Epoch 15/100
# 179/179 [==============================] - 19s 86ms/step - loss: 0.0371 - recall: 0.9986 - val_loss: 0.1387 - val_recall: 0.9634
# Epoch 16/100
# 179/179 [==============================] - 19s 86ms/step - loss: 0.0370 - recall: 0.9989 - val_loss: 0.1723 - val_recall: 0.9527
# Epoch 17/100
# 179/179 [==============================] - 19s 86ms/step - loss: 0.0348 - recall: 0.9995 - val_loss: 0.1289 - val_recall: 0.9649
# Epoch 18/100
# 179/179 [==============================] - 19s 86ms/step - loss: 0.0316 - recall: 1.0000 - val_loss: 0.1161 - val_recall: 0.9679
# Epoch 19/100
# 179/179 [==============================] - 19s 87ms/step - loss: 0.0349 - recall: 0.9986 - val_loss: 0.2505 - val_recall: 0.9359
# Epoch 20/100
# 179/179 [==============================] - 19s 86ms/step - loss: 0.0447 - recall: 0.9963 - val_loss: 0.2281 - val_recall: 0.9191
# Epoch 21/100
# 179/179 [==============================] - 19s 86ms/step - loss: 0.0422 - recall: 0.9970 - val_loss: 0.1868 - val_recall: 0.9359
# Epoch 22/100
# 179/179 [==============================] - 19s 86ms/step - loss: 0.0379 - recall: 0.9977 - val_loss: 0.1965 - val_recall: 0.9405
# Epoch 23/100
# 179/179 [==============================] - 20s 86ms/step - loss: 0.0374 - recall: 0.9982 - val_loss: 0.1199 - val_recall: 0.9695
# Epoch 24/100
# 179/179 [==============================] - 19s 86ms/step - loss: 0.0328 - recall: 0.9995 - val_loss: 0.1125 - val_recall: 0.9664
# Epoch 25/100
# 179/179 [==============================] - 19s 86ms/step - loss: 0.0358 - recall: 0.9975 - val_loss: 0.2764 - val_recall: 0.9344
# Epoch 26/100
# 179/179 [==============================] - 19s 86ms/step - loss: 0.0348 - recall: 0.9989 - val_loss: 0.1390 - val_recall: 0.9557
# Epoch 27/100
# 179/179 [==============================] - 19s 86ms/step - loss: 0.0318 - recall: 0.9993 - val_loss: 0.1652 - val_recall: 0.9588
# Epoch 28/100
# 179/179 [==============================] - 20s 86ms/step - loss: 0.0306 - recall: 0.9996 - val_loss: 0.1499 - val_recall: 0.9603
# Epoch 29/100
# 179/179 [==============================] - 20s 86ms/step - loss: 0.0302 - recall: 0.9996 - val_loss: 0.1427 - val_recall: 0.9603
# Epoch 30/100
# 179/179 [==============================] - 20s 86ms/step - loss: 0.0312 - recall: 0.9996 - val_loss: 0.1787 - val_recall: 0.9511
# Epoch 31/100
# 179/179 [==============================] - 20s 86ms/step - loss: 0.0351 - recall: 0.9975 - val_loss: 0.1536 - val_recall: 0.9511
# Epoch 32/100
# 179/179 [==============================] - 20s 86ms/step - loss: 0.0313 - recall: 0.9996 - val_loss: 0.1344 - val_recall: 0.9679
# Epoch 33/100
# 179/179 [==============================] - 20s 86ms/step - loss: 0.0309 - recall: 0.9993 - val_loss: 0.1411 - val_recall: 0.9649
# Epoch 34/100
# 179/179 [==============================] - 20s 86ms/step - loss: 0.0311 - recall: 0.9993 - val_loss: 0.1757 - val_recall: 0.9634

# %%
fig, axes = plt.subplots(1, 2, figsize = (12, 5))

axes[0].plot(history.history["recall"], label = "Train Recall")
axes[0].plot(history.history["val_recall"], label = "Validation Recall")
axes[0].set_title("Model Recall")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Recall")
axes[0].legend()

axes[1].plot(history.history["loss"], label = "Train Loss")
axes[1].plot(history.history["val_loss"], label = "Validation Loss")
axes[1].set_title("Model Loss")
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("Loss")
axes[1].legend()

plt.show()

# %%
y_prob_cnn = cnn.predict(test_ds)
y_pred_cnn= np.argmax(y_prob_cnn, axis = 1)
# Out:
# 21/21 [==============================] - 1s 30ms/step

# %%
print(confusion_matrix(y_true, y_pred_cnn))
print(classification_report(y_true, y_pred_cnn, target_names = class_names))
# Out:
# [[145   5   0   0]
#  [  3 146   4   0]
#  [  0   0 203   0]
#  [  0   0   0 150]]
#               precision    recall  f1-score   support
#
#       glioma       0.98      0.97      0.97       150
#   meningioma       0.97      0.95      0.96       153
#      notumor       0.98      1.00      0.99       203
#    pituitary       1.00      1.00      1.00       150
#
#     accuracy                           0.98       656
#    macro avg       0.98      0.98      0.98       656
# weighted avg       0.98      0.98      0.98       656

# %%
cnn.save("../models/cnn-segformer")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/cnn-segformer\assets
# INFO:tensorflow:Assets written to: ../models/cnn-segformer\assets

# %% [markdown]
# ##### CNN-XGBoost

# %%
import numpy as np
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder

# %%
def extract_features(dataset, model):
    features = []
    labels = []
    
    for images, label in dataset:
        # Get CNN features
        f = model(images, training=False)  # shape: (batch_size, feature_dim)
        features.append(f.numpy())
        labels.append(label.numpy())

    # Combine all batches into arrays
    return np.vstack(features), np.argmax(np.concatenate(labels), axis = 1)

# %%
feature_extractor = get_feature_extractor()

# %%
X_train, y_train = extract_features(train_ds, feature_extractor)
X_val, y_val = extract_features(valid_ds, feature_extractor)
X_test, y_test = extract_features(test_ds, feature_extractor)

# %%
xgb = XGBClassifier(
    objective = 'multi:softmax',
    num_class = 4,
    eval_metric = 'mlogloss',
    use_label_encoder = False,
    early_stopping_rounds=10    
)

xgb.fit(X_train, y_train, eval_set = [(X_val, y_val)], verbose = True)
# Out:
# [0]	validation_0-mlogloss:1.02491
# [1]	validation_0-mlogloss:0.81805
# [2]	validation_0-mlogloss:0.68110
# [3]	validation_0-mlogloss:0.57983
# [4]	validation_0-mlogloss:0.49671
# [5]	validation_0-mlogloss:0.43379
# [6]	validation_0-mlogloss:0.38648
# [7]	validation_0-mlogloss:0.35108
# [8]	validation_0-mlogloss:0.31954
# [9]	validation_0-mlogloss:0.29829
# [10]	validation_0-mlogloss:0.27765
# [11]	validation_0-mlogloss:0.26021
# [12]	validation_0-mlogloss:0.24647
# [13]	validation_0-mlogloss:0.23462
# [14]	validation_0-mlogloss:0.22553
# [15]	validation_0-mlogloss:0.21559
# [16]	validation_0-mlogloss:0.20454
# [17]	validation_0-mlogloss:0.20001
# [18]	validation_0-mlogloss:0.19441
# [19]	validation_0-mlogloss:0.19048
# [20]	validation_0-mlogloss:0.18670
# [21]	validation_0-mlogloss:0.18314
# [22]	validation_0-mlogloss:0.18045
# [23]	validation_0-mlogloss:0.17663
# [24]	validation_0-mlogloss:0.17265
# [25]	validation_0-mlogloss:0.16924
# [26]	validation_0-mlogloss:0.16609
# [27]	validation_0-mlogloss:0.16571
# [28]	validation_0-mlogloss:0.16240
# [29]	validation_0-mlogloss:0.15953
# [30]	validation_0-mlogloss:0.15891
# [31]	validation_0-mlogloss:0.15752
# [32]	validation_0-mlogloss:0.15593
# [33]	validation_0-mlogloss:0.15594
# [34]	validation_0-mlogloss:0.15441
# [35]	validation_0-mlogloss:0.15392
# [36]	validation_0-mlogloss:0.15365
# [37]	validation_0-mlogloss:0.15255
# [38]	validation_0-mlogloss:0.15264
# [39]	validation_0-mlogloss:0.15391
# [40]	validation_0-mlogloss:0.15375
# [41]	validation_0-mlogloss:0.15322
# [42]	validation_0-mlogloss:0.15183
# [43]	validation_0-mlogloss:0.15147
# [44]	validation_0-mlogloss:0.15187
# [45]	validation_0-mlogloss:0.15208
# [46]	validation_0-mlogloss:0.15163
# [47]	validation_0-mlogloss:0.15159
# [48]	validation_0-mlogloss:0.15133
# [49]	validation_0-mlogloss:0.15148
# [50]	validation_0-mlogloss:0.15130
# [51]	validation_0-mlogloss:0.15157
# [52]	validation_0-mlogloss:0.15149
# [53]	validation_0-mlogloss:0.15070
# [54]	validation_0-mlogloss:0.15109
# [55]	validation_0-mlogloss:0.15149
# [56]	validation_0-mlogloss:0.15148
# [57]	validation_0-mlogloss:0.15039
# [58]	validation_0-mlogloss:0.15016
# [59]	validation_0-mlogloss:0.14991
# [60]	validation_0-mlogloss:0.14962
# [61]	validation_0-mlogloss:0.15048
# [62]	validation_0-mlogloss:0.15011
# [63]	validation_0-mlogloss:0.14984
# [64]	validation_0-mlogloss:0.15015
# [65]	validation_0-mlogloss:0.14982
# [66]	validation_0-mlogloss:0.14919
# [67]	validation_0-mlogloss:0.14824
# [68]	validation_0-mlogloss:0.14747
# [69]	validation_0-mlogloss:0.14769
# [70]	validation_0-mlogloss:0.14765
# [71]	validation_0-mlogloss:0.14790
# [72]	validation_0-mlogloss:0.14792
# [73]	validation_0-mlogloss:0.14761
# [74]	validation_0-mlogloss:0.14773
# [75]	validation_0-mlogloss:0.14718
# [76]	validation_0-mlogloss:0.14676
# [77]	validation_0-mlogloss:0.14668
# [78]	validation_0-mlogloss:0.14698
# [79]	validation_0-mlogloss:0.14694
# [80]	validation_0-mlogloss:0.14704
# [81]	validation_0-mlogloss:0.14706
# [82]	validation_0-mlogloss:0.14678
# [83]	validation_0-mlogloss:0.14671
# [84]	validation_0-mlogloss:0.14640
# [85]	validation_0-mlogloss:0.14627
# [86]	validation_0-mlogloss:0.14640
# [87]	validation_0-mlogloss:0.14672
# [88]	validation_0-mlogloss:0.14578
# [89]	validation_0-mlogloss:0.14531
# [90]	validation_0-mlogloss:0.14518
# [91]	validation_0-mlogloss:0.14516
# [92]	validation_0-mlogloss:0.14526
# [93]	validation_0-mlogloss:0.14564
# [94]	validation_0-mlogloss:0.14545
# [95]	validation_0-mlogloss:0.14512
# [96]	validation_0-mlogloss:0.14545
# [97]	validation_0-mlogloss:0.14581
# [98]	validation_0-mlogloss:0.14596
# [99]	validation_0-mlogloss:0.14617
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None, num_class=4, ...)

# %%
y_pred_xgb = xgb.predict(X_test)

# %%
print(confusion_matrix(y_true, y_pred_xgb))
print(classification_report(y_true, y_pred_xgb, target_names = class_names))
# Out:
# [[133  16   0   1]
#  [  1 145   6   1]
#  [  0   0 203   0]
#  [  0   2   0 148]]
#               precision    recall  f1-score   support
#
#       glioma       0.99      0.89      0.94       150
#   meningioma       0.89      0.95      0.92       153
#      notumor       0.97      1.00      0.99       203
#    pituitary       0.99      0.99      0.99       150
#
#     accuracy                           0.96       656
#    macro avg       0.96      0.96      0.96       656
# weighted avg       0.96      0.96      0.96       656

# %%
import pickle

# %%
with open('../models/xgb-segformer.pkl', 'wb') as f:
    pickle.dump(xgb, f)
