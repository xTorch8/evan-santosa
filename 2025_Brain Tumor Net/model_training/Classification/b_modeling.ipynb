# %% [markdown]
# # Brain Tumor Classification With UNet's Segmentation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import tensorflow_addons as tfa
import os
import cv2

# %% [markdown]
# ### Data Preparation

# %%
def get_df(original_images_dir, masked_images_dir):
    class_names = os.listdir(original_images_dir)

    original_file_path = []
    masked_file_path = []
    classes = []
    for class_name in class_names:
        for file_name in os.listdir(os.path.join(original_images_dir, class_name)):
            masked_file_path.append(os.path.join(masked_images_dir, class_name, file_name))
            original_file_path.append(os.path.join(original_images_dir, class_name, file_name))
            classes.append(class_name)

    df = pd.DataFrame({
        "OriginalPath": original_file_path,
        "MaskedPath": masked_file_path,
        "Class": classes
    })

    return df

# %%
train_df = get_df("../data/original/original/Training", "../data/unet/unet/Training")
test_df = get_df("../data/original/original/Testing", "../data/unet/unet/Testing")

# %% [markdown]
# ### Data Preprocessing

# %%
from sklearn.model_selection import train_test_split

# %%
valid_df, test_df = train_test_split(test_df, test_size = 0.5, random_state = 42, stratify = test_df["Class"], shuffle = True)

# %%
class_names = sorted(train_df['Class'].unique())
class_to_index = {name: i for i, name in enumerate(class_names)}

def load_and_combine(image_path, mask_path):
    # Load and decode image and mask
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=1)  # Use channels=1 for grayscale
    image = tf.image.convert_image_dtype(image, tf.float32)

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.convert_image_dtype(mask, tf.float32)

    # Resize if needed (optional)
    image = tf.image.resize(image, [224, 224])
    mask = tf.image.resize(mask, [224, 224])

    # Concatenate along the channel axis
    combined = tf.concat([image, mask], axis = -1)  # Shape: (H, W, 2)

    return combined

def preprocess(image_path, mask_path, label):
    combined = load_and_combine(image_path, mask_path)
    label_one_hot = tf.one_hot(label, depth=4)
    return combined, label_one_hot

def create_dataset(df, class_to_index, batch_size=32, shuffle=True):
    image_paths = df["OriginalPath"].values
    mask_paths = df["MaskedPath"].values
    labels = df["Class"].map(class_to_index).values

    ds = tf.data.Dataset.from_tensor_slices((image_paths, mask_paths, labels))
    ds = ds.map(lambda x, y, z: preprocess(x, y, z), num_parallel_calls=tf.data.AUTOTUNE)

    if shuffle:
        ds = ds.shuffle(buffer_size=len(df))

    ds = ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return ds

# %%
train_ds = create_dataset(train_df, class_to_index)
valid_ds = create_dataset(valid_df, class_to_index, shuffle = False)
test_ds = create_dataset(test_df, class_to_index, shuffle = False)

# %% [markdown]
# ### Modeling

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
y_true = test_df["Class"].map(class_to_index)

# %%
y_true_one_hot = tf.keras.utils.to_categorical(y_true, num_classes = 4)

# %% [markdown]
# ##### 1. CNN

# %%
def get_feature_extractor():
    cnn = tf.keras.models.Sequential()    

    # Convulational Layer 1
    cnn.add(tf.keras.layers.Conv2D(
        filters = 32, 
        kernel_size = 3, 
        input_shape = [224, 224, 2], 
        kernel_regularizer = tf.keras.regularizers.l2(0.00005),
        padding = "same"
    ))
    cnn.add(tf.keras.layers.BatchNormalization())
    cnn.add(tf.keras.layers.ReLU())

    # Pooling Layer 1
    cnn.add(tf.keras.layers.MaxPool2D(
        pool_size = 2, 
        strides = 2
    ))

    # Convulational Layer 2
    cnn.add(tf.keras.layers.Conv2D(
        filters = 64, 
        kernel_size = 3, 
        kernel_regularizer = tf.keras.regularizers.l2(0.00005),
        padding = "same"
    ))
    cnn.add(tf.keras.layers.BatchNormalization())
    cnn.add(tf.keras.layers.ReLU())

    # Pooling Layer 2
    cnn.add(tf.keras.layers.MaxPool2D(
        pool_size = 2, 
        strides = 2
    ))

    # Convulational Layer 3
    cnn.add(tf.keras.layers.Conv2D(
        filters = 128, 
        kernel_size = 3, 
        kernel_regularizer = tf.keras.regularizers.l2(0.00005),
        padding = "same"
    ))
    cnn.add(tf.keras.layers.BatchNormalization())
    cnn.add(tf.keras.layers.ReLU())

    # Pooling Layer 3
    cnn.add(tf.keras.layers.MaxPool2D(
        pool_size = 2, 
        strides = 2
    ))

    # Convulational Layer 4
    cnn.add(tf.keras.layers.Conv2D(
        filters = 128, 
        kernel_size = 3, 
        kernel_regularizer = tf.keras.regularizers.l2(0.00005),
        padding = "same"
    ))
    cnn.add(tf.keras.layers.BatchNormalization())
    cnn.add(tf.keras.layers.ReLU())

    # Pooling Layer 4
    cnn.add(tf.keras.layers.MaxPool2D(
        pool_size = 2, 
        strides = 2
    ))  
 
    # Flatten Layer 
    cnn.add(tf.keras.layers.Flatten())  

    return cnn

# %%
cnn = get_feature_extractor()

# Fully Connected Layer 1
cnn.add(tf.keras.layers.Dense(
    units = 128,
    kernel_regularizer = tf.keras.regularizers.l2(0.00005)
))
cnn.add(tf.keras.layers.BatchNormalization())
cnn.add(tf.keras.layers.ReLU())


# Droput Layer
cnn.add(tf.keras.layers.Dropout(0.4))

# Output Layer
cnn.add(tf.keras.layers.Dense(
    units = 4, 
    activation = "softmax"
))

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      608
#
#  batch_normalization (BatchN  (None, 224, 224, 32)     128
#  ormalization)
#
#  re_lu (ReLU)                (None, 224, 224, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)      18496
#
#  batch_normalization_1 (Batc  (None, 112, 112, 64)     256
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 112, 112, 64)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 56, 56, 128)      512
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 56, 56, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 28, 28, 128)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 128)               3211392
#
#  batch_normalization_4 (Batc  (None, 128)              512
#  hNormalization)
#
#  re_lu_4 (ReLU)              (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 3,454,372
# Trainable params: 3,453,412
# Non-trainable params: 960
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor = "val_loss", 
    patience = 10, 
    restore_best_weights = True
)

# %%
cnn.compile(
    optimizer = tf.keras.optimizers.Adam(
        learning_rate = tf.keras.optimizers.schedules.ExponentialDecay(
            initial_learning_rate = 1e-4,
            decay_steps = 1000,
            decay_rate = 0.95
        )
    ), 
    loss = "categorical_crossentropy", 
    metrics = [tf.keras.metrics.Recall()]
)

# %%
history = cnn.fit(
    train_ds, 
    validation_data = valid_ds, 
    epochs = 100, 
    callbacks = [early_stopping]
)
# Out:
# Epoch 1/100
# 179/179 [==============================] - 27s 87ms/step - loss: 0.5220 - recall: 0.7981 - val_loss: 1.5250 - val_recall: 0.2290
# Epoch 2/100
# 179/179 [==============================] - 17s 83ms/step - loss: 0.2425 - recall: 0.9209 - val_loss: 0.7755 - val_recall: 0.5298
# Epoch 3/100
# 179/179 [==============================] - 17s 84ms/step - loss: 0.1500 - recall: 0.9625 - val_loss: 0.5748 - val_recall: 0.7466
# Epoch 4/100
# 179/179 [==============================] - 18s 85ms/step - loss: 0.1105 - recall: 0.9760 - val_loss: 0.2574 - val_recall: 0.8977
# Epoch 5/100
# 179/179 [==============================] - 18s 86ms/step - loss: 0.0928 - recall: 0.9811 - val_loss: 0.1341 - val_recall: 0.9664
# Epoch 6/100
# 179/179 [==============================] - 18s 85ms/step - loss: 0.0663 - recall: 0.9925 - val_loss: 0.1597 - val_recall: 0.9527
# Epoch 7/100
# 179/179 [==============================] - 18s 87ms/step - loss: 0.0612 - recall: 0.9928 - val_loss: 0.1015 - val_recall: 0.9817
# Epoch 8/100
# 179/179 [==============================] - 18s 85ms/step - loss: 0.0481 - recall: 0.9977 - val_loss: 0.1003 - val_recall: 0.9725
# Epoch 9/100
# 179/179 [==============================] - 18s 84ms/step - loss: 0.0514 - recall: 0.9970 - val_loss: 0.1678 - val_recall: 0.9359
# Epoch 10/100
# 179/179 [==============================] - 18s 85ms/step - loss: 0.0444 - recall: 0.9982 - val_loss: 0.0824 - val_recall: 0.9802
# Epoch 11/100
# 179/179 [==============================] - 18s 85ms/step - loss: 0.0434 - recall: 0.9970 - val_loss: 0.1092 - val_recall: 0.9634
# Epoch 12/100
# 179/179 [==============================] - 18s 85ms/step - loss: 0.0388 - recall: 0.9988 - val_loss: 0.0844 - val_recall: 0.9740
# Epoch 13/100
# 179/179 [==============================] - 18s 83ms/step - loss: 0.0370 - recall: 0.9996 - val_loss: 0.0779 - val_recall: 0.9817
# Epoch 14/100
# 179/179 [==============================] - 18s 83ms/step - loss: 0.0374 - recall: 0.9988 - val_loss: 0.0830 - val_recall: 0.9786
# Epoch 15/100
# 179/179 [==============================] - 18s 83ms/step - loss: 0.0339 - recall: 0.9998 - val_loss: 0.0942 - val_recall: 0.9771
# Epoch 16/100
# 179/179 [==============================] - 18s 83ms/step - loss: 0.0320 - recall: 0.9998 - val_loss: 0.1354 - val_recall: 0.9527
# Epoch 17/100
# 179/179 [==============================] - 18s 84ms/step - loss: 0.0317 - recall: 1.0000 - val_loss: 0.0902 - val_recall: 0.9771
# Epoch 18/100
# 179/179 [==============================] - 19s 85ms/step - loss: 0.0331 - recall: 0.9993 - val_loss: 0.1929 - val_recall: 0.9389
# Epoch 19/100
# 179/179 [==============================] - 19s 85ms/step - loss: 0.0426 - recall: 0.9970 - val_loss: 0.6228 - val_recall: 0.7771
# Epoch 20/100
# 179/179 [==============================] - 18s 83ms/step - loss: 0.0400 - recall: 0.9979 - val_loss: 0.1013 - val_recall: 0.9786
# Epoch 21/100
# 179/179 [==============================] - 19s 83ms/step - loss: 0.0355 - recall: 0.9986 - val_loss: 0.1539 - val_recall: 0.9557
# Epoch 22/100
# 179/179 [==============================] - 19s 83ms/step - loss: 0.0352 - recall: 0.9988 - val_loss: 0.0979 - val_recall: 0.9786
# Epoch 23/100
# 179/179 [==============================] - 19s 84ms/step - loss: 0.0311 - recall: 1.0000 - val_loss: 0.0717 - val_recall: 0.9847
# Epoch 24/100
# 179/179 [==============================] - 19s 83ms/step - loss: 0.0370 - recall: 0.9977 - val_loss: 0.0861 - val_recall: 0.9802
# Epoch 25/100
# 179/179 [==============================] - 19s 84ms/step - loss: 0.0310 - recall: 1.0000 - val_loss: 0.0875 - val_recall: 0.9832
# Epoch 26/100
# 179/179 [==============================] - 19s 84ms/step - loss: 0.0308 - recall: 0.9995 - val_loss: 0.0713 - val_recall: 0.9847
# Epoch 27/100
# 179/179 [==============================] - 19s 83ms/step - loss: 0.0293 - recall: 1.0000 - val_loss: 0.0680 - val_recall: 0.9832
# Epoch 28/100
# 179/179 [==============================] - 19s 83ms/step - loss: 0.0348 - recall: 0.9986 - val_loss: 0.1027 - val_recall: 0.9725
# Epoch 29/100
# 179/179 [==============================] - 19s 83ms/step - loss: 0.0346 - recall: 0.9982 - val_loss: 0.1008 - val_recall: 0.9756
# Epoch 30/100
# 179/179 [==============================] - 19s 83ms/step - loss: 0.0360 - recall: 0.9975 - val_loss: 0.1440 - val_recall: 0.9588
# Epoch 31/100
# 179/179 [==============================] - 19s 85ms/step - loss: 0.0388 - recall: 0.9961 - val_loss: 0.1855 - val_recall: 0.9359
# Epoch 32/100
# 179/179 [==============================] - 20s 85ms/step - loss: 0.0348 - recall: 0.9984 - val_loss: 0.0575 - val_recall: 0.9863
# Epoch 33/100
# 179/179 [==============================] - 20s 86ms/step - loss: 0.0324 - recall: 0.9986 - val_loss: 0.1966 - val_recall: 0.9298
# Epoch 34/100
# 179/179 [==============================] - 20s 85ms/step - loss: 0.0330 - recall: 0.9984 - val_loss: 0.0850 - val_recall: 0.9832
# Epoch 35/100
# 179/179 [==============================] - 19s 83ms/step - loss: 0.0298 - recall: 0.9996 - val_loss: 0.0839 - val_recall: 0.9832
# Epoch 36/100
# 179/179 [==============================] - 19s 83ms/step - loss: 0.0286 - recall: 0.9998 - val_loss: 0.0755 - val_recall: 0.9878
# Epoch 37/100
# 179/179 [==============================] - 20s 84ms/step - loss: 0.0289 - recall: 0.9995 - val_loss: 0.0599 - val_recall: 0.9893
# Epoch 38/100
# 179/179 [==============================] - 20s 84ms/step - loss: 0.0275 - recall: 1.0000 - val_loss: 0.0768 - val_recall: 0.9832
# Epoch 39/100
# 179/179 [==============================] - 20s 86ms/step - loss: 0.0270 - recall: 1.0000 - val_loss: 0.0640 - val_recall: 0.9878
# Epoch 40/100
# 179/179 [==============================] - 20s 85ms/step - loss: 0.0284 - recall: 0.9995 - val_loss: 0.0626 - val_recall: 0.9893
# Epoch 41/100
# 179/179 [==============================] - 20s 84ms/step - loss: 0.0311 - recall: 0.9986 - val_loss: 0.1109 - val_recall: 0.9710
# Epoch 42/100
# 179/179 [==============================] - 19s 83ms/step - loss: 0.0281 - recall: 0.9998 - val_loss: 0.0715 - val_recall: 0.9847

# %%
fig, axes = plt.subplots(1, 2, figsize = (12, 5))

axes[0].plot(history.history["recall"], label = "Train Recall")
axes[0].plot(history.history["val_recall"], label = "Validation Recall")
axes[0].set_title("Model Recall")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Recall")
axes[0].legend()

axes[1].plot(history.history["loss"], label = "Train Loss")
axes[1].plot(history.history["val_loss"], label = "Validation Loss")
axes[1].set_title("Model Loss")
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("Loss")
axes[1].legend()

plt.show()

# %%
y_prob_cnn = cnn.predict(test_ds)
y_pred_cnn= np.argmax(y_prob_cnn, axis = 1)
# Out:
# 21/21 [==============================] - 1s 20ms/step

# %%
print(confusion_matrix(y_true, y_pred_cnn))
print(classification_report(y_true, y_pred_cnn, target_names = class_names))
# Out:
# [[145   5   0   0]
#  [  2 147   4   0]
#  [  0   0 203   0]
#  [  0   0   0 150]]
#               precision    recall  f1-score   support
#
#       glioma       0.99      0.97      0.98       150
#   meningioma       0.97      0.96      0.96       153
#      notumor       0.98      1.00      0.99       203
#    pituitary       1.00      1.00      1.00       150
#
#     accuracy                           0.98       656
#    macro avg       0.98      0.98      0.98       656
# weighted avg       0.98      0.98      0.98       656

# %%
cnn.save("../models/cnn-unet")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/cnn-unet\assets
# INFO:tensorflow:Assets written to: ../models/cnn-unet\assets

# %% [markdown]
# ##### CNN-XGBoost

# %%
import numpy as np
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder

# %%
def extract_features(dataset, model):
    features = []
    labels = []
    
    for images, label in dataset:
        # Get CNN features
        f = model(images, training=False)  # shape: (batch_size, feature_dim)
        features.append(f.numpy())
        labels.append(label.numpy())

    # Combine all batches into arrays
    return np.vstack(features), np.argmax(np.concatenate(labels), axis = 1)

# %%
feature_extractor = get_feature_extractor()

# %%
X_train, y_train = extract_features(train_ds, feature_extractor)
X_val, y_val = extract_features(valid_ds, feature_extractor)
X_test, y_test = extract_features(test_ds, feature_extractor)

# %%
xgb = XGBClassifier(
    objective = 'multi:softmax',
    num_class = 4,
    eval_metric = 'mlogloss',
    use_label_encoder = False,
    early_stopping_rounds=10    
)

xgb.fit(X_train, y_train, eval_set = [(X_val, y_val)], verbose = True)
# Out:
# c:\Users\PC\anaconda3\envs\main-gpu\lib\site-packages\xgboost\callback.py:386: UserWarning: [08:27:57] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:1.02973
# [1]	validation_0-mlogloss:0.83225
# [2]	validation_0-mlogloss:0.69769
# [3]	validation_0-mlogloss:0.59621
# [4]	validation_0-mlogloss:0.51375
# [5]	validation_0-mlogloss:0.44988
# [6]	validation_0-mlogloss:0.39704
# [7]	validation_0-mlogloss:0.36032
# [8]	validation_0-mlogloss:0.32721
# [9]	validation_0-mlogloss:0.30006
# [10]	validation_0-mlogloss:0.27714
# [11]	validation_0-mlogloss:0.26209
# [12]	validation_0-mlogloss:0.24556
# [13]	validation_0-mlogloss:0.23458
# [14]	validation_0-mlogloss:0.22265
# [15]	validation_0-mlogloss:0.21391
# [16]	validation_0-mlogloss:0.20601
# [17]	validation_0-mlogloss:0.19533
# [18]	validation_0-mlogloss:0.19065
# [19]	validation_0-mlogloss:0.18573
# [20]	validation_0-mlogloss:0.18147
# [21]	validation_0-mlogloss:0.17479
# [22]	validation_0-mlogloss:0.17320
# [23]	validation_0-mlogloss:0.16907
# [24]	validation_0-mlogloss:0.16268
# [25]	validation_0-mlogloss:0.15969
# [26]	validation_0-mlogloss:0.15759
# [27]	validation_0-mlogloss:0.15724
# [28]	validation_0-mlogloss:0.15647
# [29]	validation_0-mlogloss:0.15699
# [30]	validation_0-mlogloss:0.15522
# [31]	validation_0-mlogloss:0.15258
# [32]	validation_0-mlogloss:0.15071
# [33]	validation_0-mlogloss:0.14843
# [34]	validation_0-mlogloss:0.14761
# [35]	validation_0-mlogloss:0.14784
# [36]	validation_0-mlogloss:0.14623
# [37]	validation_0-mlogloss:0.14525
# [38]	validation_0-mlogloss:0.14488
# [39]	validation_0-mlogloss:0.14396
# [40]	validation_0-mlogloss:0.14273
# [41]	validation_0-mlogloss:0.14303
# [42]	validation_0-mlogloss:0.14134
# [43]	validation_0-mlogloss:0.14127
# [44]	validation_0-mlogloss:0.14176
# [45]	validation_0-mlogloss:0.14123
# [46]	validation_0-mlogloss:0.14061
# [47]	validation_0-mlogloss:0.14107
# [48]	validation_0-mlogloss:0.14034
# [49]	validation_0-mlogloss:0.14060
# [50]	validation_0-mlogloss:0.14016
# [51]	validation_0-mlogloss:0.13999
# [52]	validation_0-mlogloss:0.13969
# [53]	validation_0-mlogloss:0.13941
# [54]	validation_0-mlogloss:0.13921
# [55]	validation_0-mlogloss:0.13855
# [56]	validation_0-mlogloss:0.13831
# [57]	validation_0-mlogloss:0.13819
# [58]	validation_0-mlogloss:0.13738
# [59]	validation_0-mlogloss:0.13780
# [60]	validation_0-mlogloss:0.13762
# [61]	validation_0-mlogloss:0.13751
# [62]	validation_0-mlogloss:0.13763
# [63]	validation_0-mlogloss:0.13777
# [64]	validation_0-mlogloss:0.13757
# [65]	validation_0-mlogloss:0.13763
# [66]	validation_0-mlogloss:0.13750
# [67]	validation_0-mlogloss:0.13731
# [68]	validation_0-mlogloss:0.13816
# [69]	validation_0-mlogloss:0.13812
# [70]	validation_0-mlogloss:0.13876
# [71]	validation_0-mlogloss:0.13825
# [72]	validation_0-mlogloss:0.13798
# [73]	validation_0-mlogloss:0.13824
# [74]	validation_0-mlogloss:0.13866
# [75]	validation_0-mlogloss:0.13874
# [76]	validation_0-mlogloss:0.13869
# [77]	validation_0-mlogloss:0.13848
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None, num_class=4, ...)

# %%
y_pred_xgb = xgb.predict(X_test)

# %%
print(confusion_matrix(y_true, y_pred_xgb))
print(classification_report(y_true, y_pred_xgb, target_names = class_names))
# Out:
# [[136  14   0   0]
#  [  2 145   6   0]
#  [  0   0 203   0]
#  [  1   0   0 149]]
#               precision    recall  f1-score   support
#
#       glioma       0.98      0.91      0.94       150
#   meningioma       0.91      0.95      0.93       153
#      notumor       0.97      1.00      0.99       203
#    pituitary       1.00      0.99      1.00       150
#
#     accuracy                           0.96       656
#    macro avg       0.97      0.96      0.96       656
# weighted avg       0.97      0.96      0.96       656
